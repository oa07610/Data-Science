# %% [markdown]
# ## CS/CE 457/464 Homework 02

# %% [markdown]
# ## Owais Aijaz 7610
# ## oa07610@st.habib.edu.pk

# %% [markdown]
# ## Part 1

# %%
import pandas as pd
import seaborn as sns                      
import matplotlib.pyplot as plt             
# %matplotlib inline
pd.set_option('chained_assignment',None)

# %%
df = pd.read_csv('FIFA_Players_Data.csv')
df.head()
# Out:
#    sofifa_id         short_name                            long_name  age  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2       9014          A. Robben                         Arjen Robben   30
# 3      41236     Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4     167495           M. Neuer                         Manuel Neuer   28
#
#          dob  height_cm  weight_kg  nationality                 club  overall  \
# 0  6/24/1987        169         67    Argentina         FC Barcelona       93
# 1   2/5/1985        185         80     Portugal          Real Madrid       92
# 2  1/23/1984        180         80  Netherlands    FC Bayern München       90
# 3  10/3/1981        195         95       Sweden  Paris Saint-Germain       90
# 4  3/27/1986        193         92      Germany    FC Bayern München       90
#
#    ...  nation_position nation_jersey_number  pace  shooting  passing  \
# 0  ...               CF                 10.0  93.0      89.0     86.0
# 1  ...               LW                  7.0  93.0      93.0     81.0
# 2  ...               RS                 11.0  93.0      86.0     83.0
# 3  ...               ST                 10.0  76.0      91.0     81.0
# 4  ...               GK                  1.0   NaN       NaN      NaN
#
#    dribbling defending physic skill_ball_control  power_stamina
# 0       96.0      27.0   63.0                 96           77-1
# 1       91.0      32.0   79.0               92-3             89
# 2       92.0      32.0   64.0               90+1          78+11
# 3       86.0      34.0   86.0                 90             78
# 4        NaN       NaN    NaN                 31           44+9
#
# [5 rows x 34 columns]

# %%
df.count()
# Out:
# sofifa_id                   15465
# short_name                  15465
# long_name                   15465
# age                         15465
# dob                         15465
# height_cm                   15465
# weight_kg                   15465
# nationality                 15465
# club                        15465
# overall                     15465
# potential                   15465
# player_positions            15465
# preferred_foot              15465
# international_reputation    15465
# weak_foot                   15465
# skill_moves                 15465
# work_rate                   15465
# body_type                   15465
# real_face                   15465
# release_clause_eur              0
# team_position               15233
# team_jersey_number          15233
# joined                      14314
# contract_valid_until        15226
# nation_position              1056
# nation_jersey_number         1056
# pace                        13762
# shooting                    13762
# passing                     13762
# dribbling                   13762
# defending                   13762
# physic                      13762
# skill_ball_control          15465
# power_stamina               15465
# dtype: int64

# %%
#Dropping duplicates
df=df.drop_duplicates()
#df.count()

#Missing Vaalues
df.isnull().sum()
# Out:
# sofifa_id                       0
# short_name                      0
# long_name                       0
# age                             0
# dob                             0
# height_cm                       0
# weight_kg                       0
# nationality                     0
# club                            0
# overall                         0
# potential                       0
# player_positions                0
# preferred_foot                  0
# international_reputation        0
# weak_foot                       0
# skill_moves                     0
# work_rate                       0
# body_type                       0
# real_face                       0
# release_clause_eur          15465
# team_position                 232
# team_jersey_number            232
# joined                       1151
# contract_valid_until          239
# nation_position             14409
# nation_jersey_number        14409
# pace                         1703
# shooting                     1703
# passing                      1703
# dribbling                    1703
# defending                    1703
# physic                       1703
# skill_ball_control              0
# power_stamina                   0
# dtype: int64

# %% [markdown]
# #### Dropping rows having nation_position and team_position GK because it had all empty values for skills and it would introduce inaccuracies if imputed. Also drooping "release_clause_eur" column as it is all empty.

# %%
df = df.drop(['release_clause_eur'], axis = 1)
df = df[df['nation_position'] != 'GK']
df = df[df['team_position'] != 'GK']

df.head()
# Out:
#    sofifa_id         short_name                            long_name  age  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2       9014          A. Robben                         Arjen Robben   30
# 3      41236     Z. Ibrahimović                   Zlatan Ibrahimović   32
# 5     176580          L. Suárez             Luis Alberto Suárez Díaz   27
#
#          dob  height_cm  weight_kg  nationality                 club  overall  \
# 0  6/24/1987        169         67    Argentina         FC Barcelona       93
# 1   2/5/1985        185         80     Portugal          Real Madrid       92
# 2  1/23/1984        180         80  Netherlands    FC Bayern München       90
# 3  10/3/1981        195         95       Sweden  Paris Saint-Germain       90
# 5  1/24/1987        181         81      Uruguay         FC Barcelona       89
#
#    ...  nation_position nation_jersey_number  pace  shooting  passing  \
# 0  ...               CF                 10.0  93.0      89.0     86.0
# 1  ...               LW                  7.0  93.0      93.0     81.0
# 2  ...               RS                 11.0  93.0      86.0     83.0
# 3  ...               ST                 10.0  76.0      91.0     81.0
# 5  ...              NaN                  NaN  83.0      87.0     79.0
#
#    dribbling defending physic skill_ball_control power_stamina
# 0       96.0      27.0   63.0                 96          77-1
# 1       91.0      32.0   79.0               92-3            89
# 2       92.0      32.0   64.0               90+1         78+11
# 3       86.0      34.0   86.0                 90            78
# 5       88.0      42.0   79.0                 89            86
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# sofifa_id                       0
# short_name                      0
# long_name                       0
# age                             0
# dob                             0
# height_cm                       0
# weight_kg                       0
# nationality                     0
# club                            0
# overall                         0
# potential                       0
# player_positions                0
# preferred_foot                  0
# international_reputation        0
# weak_foot                       0
# skill_moves                     0
# work_rate                       0
# body_type                       0
# real_face                       0
# team_position                 224
# team_jersey_number            224
# joined                       1102
# contract_valid_until          231
# nation_position             13935
# nation_jersey_number        13935
# pace                         1131
# shooting                     1131
# passing                      1131
# dribbling                    1131
# defending                    1131
# physic                       1131
# skill_ball_control              0
# power_stamina                   0
# dtype: int64

# %% [markdown]
# #### Filling in missing values for the rest of the columns having null values using appropriate method

# %%
#df.isnull().sum()

#Using mode to fill in the missing values of categorical data

df['joined'].fillna(df['joined'].mode()[0], inplace=True)
df['nation_position'].fillna(df['nation_position'].mode()[0], inplace=True)
df['team_position'].fillna(df['team_position'].mode()[0], inplace=True)
df['contract_valid_until'].fillna(df['contract_valid_until'].mode()[0], inplace=True)

#Using median to fill in the missing values of ordinal data

df['team_jersey_number'].fillna(df['team_jersey_number'].median(), inplace=True)
df['nation_jersey_number'].fillna(df['nation_jersey_number'].median(), inplace=True)

#Using mean of the same attribute of players of same position to fill in the missing values of attributes

columns_to_fill = ['pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic']

for col in columns_to_fill:
    df[col] = df.groupby('team_position')[col].transform(lambda x: x.fillna(x.mean()))

df.isnull().sum()
# Out:
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\1684738618.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['joined'].fillna(df['joined'].mode()[0], inplace=True)
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\1684738618.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nation_position'].fillna(df['nation_position'].mode()[0], inplace=True)
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\1684738618.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['team_position'].fillna(df['team_position'].mode()[0], inplace=True)
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\1684738618.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['contract_valid_until'].fillna(df['contract_valid_until'].mode()[0], inplace=True)
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\1684738618.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['team_jersey_number'].fillna(df['team_jersey_number'].median(), inplace=True)
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\1684738618.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nation_jersey_number'].fillna(df['nation_jersey_number'].median(), inplace=True)
# sofifa_id                   0
# short_name                  0
# long_name                   0
# age                         0
# dob                         0
# height_cm                   0
# weight_kg                   0
# nationality                 0
# club                        0
# overall                     0
# potential                   0
# player_positions            0
# preferred_foot              0
# international_reputation    0
# weak_foot                   0
# skill_moves                 0
# work_rate                   0
# body_type                   0
# real_face                   0
# team_position               0
# team_jersey_number          0
# joined                      0
# contract_valid_until        0
# nation_position             0
# nation_jersey_number        0
# pace                        0
# shooting                    0
# passing                     0
# dribbling                   0
# defending                   0
# physic                      0
# skill_ball_control          0
# power_stamina               0
# dtype: int64

# %% [markdown]
# #### Processing the values for skill_ball_control and power_stamina

# %%
#Function to evaluate +/- in the value, split, then apply operation
def resolve_operation(value):
    if '-' in value:
        parts = value.split('-')
        return int(parts[0]) - int(parts[1])
    elif '+' in value:
        parts = value.split('+')
        return int(parts[0]) + int(parts[1])
    else:
        return int(value)

#Apply the function to the desired columns
df['skill_ball_control'] = df['skill_ball_control'].apply(resolve_operation)
df['power_stamina'] = df['power_stamina'].apply(resolve_operation)

df.head()
# Out:
#    sofifa_id         short_name                            long_name  age  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2       9014          A. Robben                         Arjen Robben   30
# 3      41236     Z. Ibrahimović                   Zlatan Ibrahimović   32
# 5     176580          L. Suárez             Luis Alberto Suárez Díaz   27
#
#          dob  height_cm  weight_kg  nationality                 club  overall  \
# 0  6/24/1987        169         67    Argentina         FC Barcelona       93
# 1   2/5/1985        185         80     Portugal          Real Madrid       92
# 2  1/23/1984        180         80  Netherlands    FC Bayern München       90
# 3  10/3/1981        195         95       Sweden  Paris Saint-Germain       90
# 5  1/24/1987        181         81      Uruguay         FC Barcelona       89
#
#    ...  nation_position nation_jersey_number  pace  shooting  passing  \
# 0  ...               CF                 10.0  93.0      89.0     86.0
# 1  ...               LW                  7.0  93.0      93.0     81.0
# 2  ...               RS                 11.0  93.0      86.0     83.0
# 3  ...               ST                 10.0  76.0      91.0     81.0
# 5  ...              SUB                 12.0  83.0      87.0     79.0
#
#    dribbling defending physic skill_ball_control power_stamina
# 0       96.0      27.0   63.0                 96            76
# 1       91.0      32.0   79.0                 89            89
# 2       92.0      32.0   64.0                 91            89
# 3       86.0      34.0   86.0                 90            78
# 5       88.0      42.0   79.0                 89            86
#
# [5 rows x 33 columns]

# %%
#Converting it to CSV file 
df.to_csv('final_players_database.csv', index = False)

# %% [markdown]
# ## Part 2

# %%
df = pd.read_csv('final_players_database.csv')
df.head()
# Out:
#    sofifa_id         short_name                            long_name  age  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2       9014          A. Robben                         Arjen Robben   30
# 3      41236     Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4     176580          L. Suárez             Luis Alberto Suárez Díaz   27
#
#          dob  height_cm  weight_kg  nationality                 club  overall  \
# 0  6/24/1987        169         67    Argentina         FC Barcelona       93
# 1   2/5/1985        185         80     Portugal          Real Madrid       92
# 2  1/23/1984        180         80  Netherlands    FC Bayern München       90
# 3  10/3/1981        195         95       Sweden  Paris Saint-Germain       90
# 4  1/24/1987        181         81      Uruguay         FC Barcelona       89
#
#    ...  nation_position nation_jersey_number  pace  shooting  passing  \
# 0  ...               CF                 10.0  93.0      89.0     86.0
# 1  ...               LW                  7.0  93.0      93.0     81.0
# 2  ...               RS                 11.0  93.0      86.0     83.0
# 3  ...               ST                 10.0  76.0      91.0     81.0
# 4  ...              SUB                 12.0  83.0      87.0     79.0
#
#    dribbling defending physic skill_ball_control power_stamina
# 0       96.0      27.0   63.0                 96            76
# 1       91.0      32.0   79.0                 89            89
# 2       92.0      32.0   64.0                 91            89
# 3       86.0      34.0   86.0                 90            78
# 4       88.0      42.0   79.0                 89            86
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Generating summaries and insights

# %% [markdown]
# ### Univariate Analysis

# %%
df['age'].hist(bins=20, figsize=(8, 4))
plt.title('Histogram: Distribution of Player Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Getting the top 10 nationalities having highest overall
top_10_nationalities = df.groupby('nationality')['overall'].mean().nlargest(10).index

#Filter the DataFrame to include only these top 10 nationalities
filtered_df = df[df['nationality'].isin(top_10_nationalities)]

#Generate the violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='nationality', y='overall', data=filtered_df, scale='width', inner='quartile')
plt.title('Distribution of Overall Ratings by Top 10 Nationalities')
plt.xlabel('Nationality')
plt.ylabel('Overall Rating')
plt.show()
# Out:
# C:\Users\ryash\AppData\Local\Temp\ipykernel_16896\803506790.py:9: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x='nationality', y='overall', data=filtered_df, scale='width', inner='quartile')

# %%
df['height_cm'].hist(bins=20, figsize=(8, 4))
plt.title('Distribution of Player Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['skill_ball_control'], bins=20, kde=True)
plt.title('Bar Chart: Distribution of Skill Ball Control')
plt.xlabel('Skill Ball Control')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
df.plot(kind='scatter', x='pace', y='dribbling', alpha=0.5, figsize=(8, 4))
plt.title('Pace vs. Dribbling')
plt.xlabel('Pace')
plt.ylabel('Dribbling')
plt.show()

# %%
df.plot(kind='scatter', x='overall', y='potential', alpha=0.5, figsize=(8, 4))
plt.title('Overall Rating vs. Potential')
plt.xlabel('Overall Rating')
plt.ylabel('Potential')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='team_position', y='shooting', data=df)
plt.title('Shooting by Team Position')
plt.xlabel('Team Position')
plt.ylabel('Shooting')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df[['pace','shooting','passing','dribbling','defending','physic','skill_ball_control', 'power_stamina']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
filtered_df = df[df['team_position'].isin(['CF', 'GK', 'CB', 'CDM'])]

# Create the catplot using the filtered DataFrame
sns.catplot(x="team_position", hue="preferred_foot", col="body_type", data=filtered_df, kind="count", height=6, aspect=1)
