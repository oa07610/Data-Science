# %%
# from nltk.tokenize import word_tokenize
# from nltk.tag import pos_tag
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
from nltk import pos_tag, word_tokenize, RegexpParser
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from bs4 import BeautifulSoup
import requests
import re
import numpy
import os
import pandas as pd
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 1. Parts of Speech Tagging

# %%
# Example text
sample_text = "I shot an elephant in my pajamas"

# %%
# Find all parts of speech in above sentence
tagged = pos_tag(word_tokenize(sample_text))
tagged
# Out:
# [('I', 'PRP'),
#  ('shot', 'VBP'),
#  ('an', 'DT'),
#  ('elephant', 'NN'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('pajamas', 'NN')]

# %%
#Extract all parts of speech from any text
#For graphics plot
chunker = RegexpParser("""
                       NP: {<DT>?<JJ>*<NN>}    #To extract Noun Phrases
                       P: {<IN>}               #To extract Prepositions
                       V: {<V.*>}              #To extract Verbs
                       PP: {<P> <NP>}          #To extract Prepostional Phrases
                       VP: {<V> <NP|PP>*}      #To extarct Verb Phrases
                       """)

# %%
# Print all parts of speech in above sentence
output = chunker.parse(tagged)

# %%
# To draw the parse tree
output.draw()

# %%
### Another example

# %%
sent = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'

# %%
sent_pos = nltk.word_tokenize(sent)
sent_pos = nltk.pos_tag(sent_pos)

# %%
sent_pos
# Out:
# [('European', 'JJ'),
#  ('authorities', 'NNS'),
#  ('fined', 'VBD'),
#  ('Google', 'NNP'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('$', '$'),
#  ('5.1', 'CD'),
#  ('billion', 'CD'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('for', 'IN'),
#  ('abusing', 'VBG'),
#  ('its', 'PRP$'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mobile', 'JJ'),
#  ('phone', 'NN'),
#  ('market', 'NN'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('to', 'TO'),
#  ('alter', 'VB'),
#  ('its', 'PRP$'),
#  ('practices', 'NNS')]

# %% [markdown]
# See all the pos tag list here
# https://www.guru99.com/pos-tagging-chunking-nltk.html

# %% [markdown]
# # 2. Name Entity Recognition (NER)
# ### SpaCy Library NER

# %%
#SpaCy’s named entity recognition has been trained on the OntoNotes 5 corpus and it supports the following entity types:

# %%
# CARDINAL, DATE, EVENT, FAC, GPE, LANGUAGE, LAW, LOC, MONEY, NORP, ORDINAL, ORG, PERCENT, PERSON, PRODUCT, QUANTITY, TIME, WORK_OF_ART

# %%
# DATE - Absolute or relative dates or periods
# PERSON - People, including fictional
# GPE - Countries, cities, states
# LOC - Non-GPE locations, mountain ranges, bodies of water
# MONEY - Monetary values, including unit
# TIME - Times smaller than a day
# PRODUCT - Objects, vehicles, foods, etc. (not services)
# CARDINAL - Numerals that do not fall under another type
# ORDINAL - "first", "second", etc.
# QUANTITY - Measurements, as of weight or distance
# EVENT - Named hurricanes, battles, wars, sports events, etc.
# FAC - Buildings, airports, highways, bridges, etc.
# LANGUAGE - Any named language
# LAW - Named documents made into laws.
# NORP - Nationalities or religious or political groups
# PERCENT - Percentage, including "%"
# WORK_OF_ART - Titles of books, songs, etc.

# %%
# nlp = en_core_web_sm.load()
nlp = spacy.load('en_core_web_sm')
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'), ('Google', 'ORG'), ('$5.1 billion', 'MONEY'), ('Wednesday', 'DATE')]

# %%
# IOB SCHEME
# I – Token is inside an entity.
# O – Token is outside an entity.
# B – Token is the beginning of an entity.

# %%
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'), (authorities, 'O', ''), (fined, 'O', ''), (Google, 'B', 'ORG'), (a, 'O', ''), (record, 'O', ''), ($, 'B', 'MONEY'), (5.1, 'I', 'MONEY'), (billion, 'I', 'MONEY'), (on, 'O', ''), (Wednesday, 'B', 'DATE'), (for, 'O', ''), (abusing, 'O', ''), (its, 'O', ''), (power, 'O', ''), (in, 'O', ''), (the, 'O', ''), (mobile, 'O', ''), (phone, 'O', ''), (market, 'O', ''), (and, 'O', ''), (ordered, 'O', ''), (the, 'O', ''), (company, 'O', ''), (to, 'O', ''), (alter, 'O', ''), (its, 'O', ''), (practices, 'O', '')]

# %% [markdown]
# ### Processing a URL

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
        return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
# ny_bb = url_to_string('https://www.cnn.com/2023/04/05/politics/trump-hush-money-indictment-bragg/index.html')
# ny_bb = url_to_string('https://www.cnn.com/2023/10/14/sport/india-pakistan-cricket-world-cup-spt-intl/index.html')
# ny_bb = url_to_string('https://www.cnn.com/2023/10/25/politics/state-dinner-joe-biden-anthony-albanese/index.html')
ny_bb = url_to_string('https://www.dawn.com/news/1870798/biden-urges-americans-to-bring-down-temperature-after-trump-win')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 230

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 49,
#          'NORP': 18,
#          'ORG': 60,
#          'DATE': 31,
#          'GPE': 40,
#          'CARDINAL': 13,
#          'FAC': 4,
#          'LAW': 2,
#          'WORK_OF_ART': 4,
#          'ORDINAL': 3,
#          'MONEY': 1,
#          'PRODUCT': 2,
#          'LOC': 2,
#          'TIME': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Trump', 25), ('US', 14), ('Biden', 13)]

# %%
sentences = [x for x in article.sents]

s = sentences[1]
print(s)
# Out:
# Biden urges Americans to ‘bring down temperature’ after Trump win - World - DAWN.COM   EPAPER LIVE TV DAWNNEWS URDU Images Herald Aurora CityFM89 Advertise Events /Supplements Classifieds Obituaries DAWN.COM E-Paper | November 08, 2024      Home          Latest          US Elections          Gaza siege          Pakistan          Opinion          Business          Images          Prism          World          Sport          Magazines

# %%
displacy.render(nlp(str(s)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  urges
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  to ‘bring down temperature’ after
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  win - World - DAWN.COM   EPAPER LIVE TV DAWNNEWS URDU Images
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Herald Aurora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  CityFM89 Advertise Events /Supplements
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Classifieds Obituaries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DAWN.COM E-Paper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  |
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 08, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#       Home          Latest
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Elections
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  siege
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#           Opinion          Business          Images          Prism          World          Sport          Magazines          </div></span>

# %%
dict([(str(x), x.label_) for x in nlp(str(s)).ents])
# Out:
# {'Biden': 'PERSON',
#  'Americans': 'NORP',
#  'Trump': 'ORG',
#  'Herald Aurora': 'PERSON',
#  'Classifieds Obituaries': 'PERSON',
#  'DAWN.COM E-Paper': 'PERSON',
#  'November 08, 2024': 'DATE',
#  'US': 'GPE',
#  'Gaza': 'GPE',
#  'Pakistan': 'GPE'}

# %% [markdown]
# #### Lemmatization

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y for y in nlp(str(s)) if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Biden', 'PROPN', 'Biden'),
#  ('urges', 'VERB', 'urge'),
#  ('Americans', 'PROPN', 'Americans'),
#  ('bring', 'VERB', 'bring'),
#  ('temperature', 'NOUN', 'temperature'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('win', 'NOUN', 'win'),
#  ('World', 'PROPN', 'World'),
#  ('DAWN.COM', 'PROPN', 'DAWN.COM'),
#  ('  ', 'SPACE', '  '),
#  ('EPAPER', 'PROPN', 'EPAPER'),
#  ('LIVE', 'VERB', 'live'),
#  ('TV', 'NOUN', 'tv'),
#  ('DAWNNEWS', 'NOUN', 'dawnnews'),
#  ('URDU', 'PROPN', 'URDU'),
#  ('Images', 'PROPN', 'Images'),
#  ('Herald', 'PROPN', 'Herald'),
#  ('Aurora', 'PROPN', 'Aurora'),
#  ('CityFM89', 'PROPN', 'CityFM89'),
#  ('Advertise', 'PROPN', 'Advertise'),
#  ('Events', 'PROPN', 'Events'),
#  ('/Supplements', 'NOUN', '/supplement'),
#  ('Classifieds', 'PROPN', 'Classifieds'),
#  ('Obituaries', 'PROPN', 'Obituaries'),
#  ('DAWN.COM', 'PROPN', 'DAWN.COM'),
#  ('E', 'PROPN', 'E'),
#  ('-', 'PROPN', '-'),
#  ('Paper', 'PROPN', 'Paper'),
#  ('|', 'NOUN', '|'),
#  ('November', 'PROPN', 'November'),
#  ('08', 'NUM', '08'),
#  ('2024', 'NUM', '2024'),
#  ('     ', 'SPACE', '     '),
#  ('Home', 'NOUN', 'home'),
#  ('         ', 'SPACE', '         '),
#  ('Latest', 'ADJ', 'late'),
#  ('         ', 'SPACE', '         '),
#  ('Elections', 'PROPN', 'Elections'),
#  ('         ', 'SPACE', '         '),
#  ('Gaza', 'PROPN', 'Gaza'),
#  ('siege', 'NOUN', 'siege'),
#  ('         ', 'SPACE', '         '),
#  ('Pakistan', 'PROPN', 'Pakistan'),
#  ('         ', 'SPACE', '         '),
#  ('Opinion', 'PROPN', 'Opinion'),
#  ('         ', 'SPACE', '         '),
#  ('Business', 'PROPN', 'Business'),
#  ('         ', 'SPACE', '         '),
#  ('Images', 'PROPN', 'Images'),
#  ('         ', 'SPACE', '         '),
#  ('Prism', 'PROPN', 'Prism'),
#  ('         ', 'SPACE', '         '),
#  ('World', 'PROPN', 'World'),
#  ('         ', 'SPACE', '         '),
#  ('Sport', 'PROPN', 'Sport'),
#  ('         ', 'SPACE', '         '),
#  ('Magazines', 'PROPN', 'Magazines'),
#  ('         ', 'SPACE', '         ')]

# %% [markdown]
# ### Full Content

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[ ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  urges
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  to ‘bring down temperature’ after
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  win - World - DAWN.COM   EPAPER LIVE TV DAWNNEWS URDU Images
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Herald Aurora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  CityFM89 Advertise Events /Supplements
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Classifieds Obituaries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DAWN.COM E-Paper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  |
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 08, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#       Home          Latest
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Elections
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  siege
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#           Opinion          Business          Images          Prism          World          Sport          Magazines          , Tech          Videos          Popular          Archive          Flood Donations          Home          Latest
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  Elections
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  siege
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#           Opinion          Business          Images          Prism          World          Sport          Magazines          , Tech          Videos          Popular          Archive          Flood Donations     Search Search       Biden urges
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  to ‘bring down temperature’ after
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  win
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#   Published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 7, 2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#    , Updated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 7, 2024 10:54pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  delivers remarks on the results of the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  election in
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Rose Garden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="

# %% [markdown]
# # 3. Text Summarization

# %% [markdown]
# ### PDF Parser - You can use any pdf reader library

# %%
from tika import parser # pip install tika

raw = parser.from_file('1708.05148.pdf')

# %%
# print(raw['content'])

# %%
tokenize_words = nltk.tokenize.word_tokenize(raw['content'])

# %% [markdown]
# #### Data Cleaning

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(["T", "J", "D", "S", "M", "H", "et al", "et", "pp", "a.", "m.", "d.", "j.", "s.", "r.", "c.", "t."])
no_stopwords = [word for word in tokenize_words if word.lower() not in stopwords]

# remove punctuation, count raw words
nonPunct = re.compile('.*[A-Za-z].*')
clean_words = [w for w in no_stopwords if nonPunct.match(w)]

# %%
filtered_word_freq = nltk.FreqDist(clean_words)
filtered_word_freq.most_common(20)
# Out:
# [('language', 66),
#  ('Language', 54),
#  ('text', 51),
#  ('information', 44),
#  ('Natural', 41),
#  ('NLP', 38),
#  ('data', 37),
#  ('words', 31),
#  ('Processing', 30),
#  ('processing', 30),
#  ('Proceedings', 29),
#  ('used', 28),
#  ('using', 26),
#  ('model', 26),
#  ('natural', 24),
#  ('word', 24),
#  ('Medical', 24),
#  ('system', 23),
#  ('systems', 23),
#  ('Association', 23)]

# %%
filtered_word_freq.plot(30,title='Frequency distribution for 30 most common tokens in our text collection (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Frequency distribution for 30 most common tokens in our text collection (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(raw['content'])
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### More Cleaning

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["T", "J", "D", "S", "M", "H", "et al", "et", "al"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=100, background_color="white").generate(raw['content'])

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # 4. Topic Modeling

# %% [markdown]
# ### RAKE Library for Text Summarization (Topic Modeling)

# %%
from rake_nltk import Rake
r = Rake()
r.extract_keywords_from_text(raw['content'])
r.get_ranked_phrases_with_scores()[:10]
# Out:
# [(78.88505776947558,
#   'rennie ., 2000 )[ 46 ][ 47 ][ 48 ], memory based learning'),
#  (65.21934709126491,
#   'androutsopoulos et al ., 2000b )[ 47 ], support vector machines'),
#  (61.88601375793157, 'druker et al ., 1999 )[ 49 ], decision trees'),
#  (60.96969696969697, '79 ][ 80 ][ 81 ][ 82 ][ 83 ].'),
#  (60.96969696969697, '74 ][ 75 ][ 76 ][ 77 ][ 78 ].'),
#  (52.08839471031252, 'pradipta ranjan ray et al ., 2003 )[ 28'),
#  (44.27348484848485,
#   'gdpr (" general data protection regulation ") compliance'),
#  (43.43030303030303,
#   'wide ranging covering usual items like word segmentation'),
#  (42.72380952380952, 'informatique et gestion des unités de soins'),
#  (41.0257053291536, 'powerful general purpose sentence processors like sri ’')]

# %% [markdown]
# ### Textacy Library for Text Summarization (Topic Modeling)

# %%
import textacy
# from textacy import *
  
#Load a spacy model, which will be used for all further processing. 
en = textacy.load_spacy_lang("en_core_web_sm")

# %%
#convert the text into a spacy document. 
doc = textacy.make_spacy_doc(raw['content'], lang=en) 
  
#Print the keywords using TextRank algorithm, as implemented in Textacy. 
print("Textrank output: \n", textacy.extract.keyterms.textrank(doc, 
                                                             normalize="lemma", 
                                                             topn=5)) 
  
# structured information extraction (textacy.extract)
print("Print all keywords output: \n")
keywords = [kps for kps, weights in 
                            textacy.extract.keyterms.textrank(doc, 
                                                              normalize="lemma")] 
print(keywords) 

# #Print the key words and phrases, using SGRank algorithm, as implemented in Textacy 
# print("SGRank output: \n", [kps for kps, weights in 
#                           textacy.extract.keyterms.sgrank(doc, topn=5)]) 
  
# # structured information extraction (textacy.extract) 
# keywords = [kps for kps, weights in 
#                             textacy.extract.keyterms.sgrank(doc, normalize="lemma")]
# Out:
# Textrank output:
#  [('natural language information processing', 0.007140267084251959), ('standard natural language processing tool', 0.006234608549333732), ('language independent knowledge representation', 0.005400005569270761), ('new machine translation system', 0.005382421996251448), ('language model', 0.00532894406679283)]
# Print all keywords output:
#
# ['natural language information processing', 'standard natural language processing tool', 'language independent knowledge representation', 'new machine translation system', 'language model', 'multi sentence text', 'statistical language processing', 'machine specific language', 'medical language processing', 'semantic use']

# %% [markdown]
# ### Yake Library for Text Summarization (Keyword Extaction)

# %%
## conda install -c conda-forge yake
import yake

# %%
kw_extractor = yake.KeywordExtractor()
language = "en"
max_ngram_size = 3
deduplication_threshold = 0.9
numOfKeywords = 20
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
keywords = custom_kw_extractor.extract_keywords(raw['content'])
for kw in keywords:
    print(kw)
# Out:
# ('Natural Language Processing', 4.072522048481498e-05)
# ('Natural Language', 0.00017630910501789887)
# ('Language Processing', 0.0002772259012794197)
# ('Language', 0.0007182928677526841)
# ('Natural Language Generation', 0.0009267846454540823)
# ('Medical language processing', 0.0011647762261847519)
# ('NLP Natural Language', 0.001337310655145573)
# ('Natural', 0.001946179856619044)
# ('Medical Informatics Association', 0.0021316055807476812)
# ('Computational Linguistics', 0.0022099659030024995)
# ('Natural Language Understanding', 0.002233998933477433)
# ('Processing', 0.0022969736217534134)
# ('language processing techniques', 0.0023694804789331256)
# ('Natural language information', 0.002410833598791504)
# ('language information processing', 0.0026347016804727564)
# ('human language', 0.0027613201712648403)
# ('NLP', 0.0030647533731460543)
# ('language processing tools', 0.003157583088635903)
# ('MEDical Language', 0.003266335063269876)
# ('text', 0.003319539662316616)

# %% [markdown]
# # 5. Sentiment Analysis

# %%
# import tweepy as tw
import json
import pandas as pd
import numpy as np
from textblob import TextBlob

# %%
#Positive +1, Negative -1

# %%
s = TextBlob('CS 457 is the best course throughout my course work')
s.sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
s = TextBlob('CS 457 is an okay course')
s.sentiment
# Out:
# Sentiment(polarity=0.5, subjectivity=0.5)

# %%
s = TextBlob('CS 457 is an average course')
s.sentiment
# Out:
# Sentiment(polarity=-0.15, subjectivity=0.39999999999999997)

# %%
s = TextBlob('CS 457 is the worst course I have ever taken')
s.sentiment
# Out:
# Sentiment(polarity=-1.0, subjectivity=1.0)

# %% [markdown]
# # 6. WordCloud with Twitter Data

# %%
twittertext = open('ElonMusk2.txt','r',encoding='utf-8')

# %%
corpus = twittertext.read()
corpus
# Out:
# '\nElon Musk\n\n@elonmusk\n·\nNov 6\nThe truth will set you free\n0:00 / 5:01\nFrom \nSMX 🇺🇸\nElon Musk\n\n@elonmusk\n·\nNov 6\nThe people of America have spoken and spoken with absolute clarity\nQuote\nCollin Rugg\n@CollinRugg\n·\nNov 6\nJUST IN: The Department of Justice and Jack Smith immediately end their cases against Donald Trump.\n\nThe DOJ cited their policy that presidents can\'t be prosecuted however it was assumed they would work up until the "last day."\n\n"What\'s interesting here is that the DOJ is moving\nShow more\n0:00 / 2:04\nElon Musk\n\n@elonmusk\n·\nNov 6\n0:00 / 1:25\nFrom \nMike Benz\nElon Musk\n\n@elonmusk\n·\nNov 6\nYup\nQuote\nELON DOCS\n@elon_docs\n·\nNov 6\nElon Musk: Trump going on lengthy podcasts made a big difference.\n\n“I think it made a big difference that President Trump and soon-to-be Vice President Vance went on lengthy podcasts.\n\nI think this really makes a difference because people look at Joe Rogan\'s podcast, which is\nShow more\n0:00 / 1:08\nElon Musk\n\n@elonmusk\n·\nNov 6\nLFG\nQuote\nELON DOCS\n@elon_docs\n·\nNov 6\nElon Musk: This is a new era in space exploration.\n\n“I do think what this heralds really is fundamentally a new era in spaceflight, a new era in space exploration.\n\nWe\'re going to go to the moon, we\'re going to have a base on the moon, we\'re going to send people to Mars and make\nShow more\n'

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
# stopwords.update(["T", "J", "D", "S", "M", "H", "et al"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=100, background_color="white").generate(corpus)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # 7. Content based Recommendation Engine

# %%
resume = pd.read_csv('job_description_data.csv')

# %%
resume.head()
# Out:
#    id                                           all_text
# 0   0  Flutter Developer. We are looking for hire exp...
# 1   1  Django Developer. PYTHON/DJANGO (Developer/Lea...
# 2   2  Machine Learning. Data Scientist (Contractor)\...
# 3   3  iOS Developer. JOB DESCRIPTION:\n\nStrong fram...
# 4   4  Full Stack Developer. job responsibility full ...

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import stopwords
import re
import string
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
stop = stopwords.words('english')
stop_words_ = set(stopwords.words('english'))
wn = WordNetLemmatizer()

# %%
def clean_more_txt(token):
    return  token not in stop_words_ and token not in list(string.punctuation)  and len(token)>2   
  
def clean_txt(text):
  clean_text = []
  clean_text2 = []
  text = re.sub("'", "",str(text))
  text=re.sub("(\\d|\\W)+"," ",str(text))
  text = text.replace("nbsp", "")
  clean_text = [ wn.lemmatize(word, pos="v") for word in word_tokenize(text.lower()) if clean_more_txt(word)]
  clean_text2 = [word for word in clean_text if clean_more_txt(word)]
  return " ".join(clean_text2)

# %%
resume['clean_text'] = resume['all_text'].apply(clean_txt)

# %%
resume.head()
# Out:
#    id                                           all_text  \
# 0   0  Flutter Developer. We are looking for hire exp...
# 1   1  Django Developer. PYTHON/DJANGO (Developer/Lea...
# 2   2  Machine Learning. Data Scientist (Contractor)\...
# 3   3  iOS Developer. JOB DESCRIPTION:\n\nStrong fram...
# 4   4  Full Stack Developer. job responsibility full ...
#
#                                           clean_text
# 0  flutter developer look hire experts flutter de...
# 1  django developer python django developer lead ...
# 2  machine learn data scientist contractor bangal...
# 3  ios developer job description strong framework...
# 4  full stack developer job responsibility full s...

# %% [markdown]
# ### Using TF-IDF Method

# %%
#initializing tfidf vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

tfidf_jobid = tfidf_vectorizer.fit_transform((resume['clean_text'])) #fitting and transforming the vector
tfidf_jobid
# Out:
# <2277x12613 sparse matrix of type '<class 'numpy.float64'>'
# 	with 311602 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ![TFIDF](tfidf.png)

# %%
resume['clean_text'][0]
# Out:
# 'flutter developer look hire experts flutter developer eligible post apply resume job type full time part time salary per month benefit flexible schedule food allowance schedule day shift supplemental pay join bonus overtime pay experience total work year prefer house rent subsidy yes industry software development work remotely temporarily due covid'

# %%
print(tfidf_jobid[0,:])
# Out:
#   (0, 2633)	0.1317952898852959
#   (0, 3490)	0.12928733277709226
#   (0, 11226)	0.13516044695477236
#   (0, 9423)	0.09868140696226321
#   (0, 3158)	0.056451953350548464
#   (0, 10444)	0.06750744494032161
#   (0, 5601)	0.09971016462660716
#   (0, 12541)	0.16313970382836854
#   (0, 10878)	0.28069202074188515
#   (0, 9438)	0.27516801093750204
#   (0, 5262)	0.18979586614424462
#   (0, 8682)	0.07505666934598822
#   (0, 12532)	0.07733209582752955
#   (0, 12420)	0.09538840502183418
#   (0, 11452)	0.10443414559766755
#   (0, 4079)	0.044108771035874586
#   (0, 8083)	0.21294640055030273
#   (0, 1415)	0.14545693363987525
#   (0, 6127)	0.11102018537293078
#   (0, 8227)	0.2425823347152751
#   (0, 10949)	0.16079429554514366
#   (0, 10200)	0.10360839716914426
#   (0, 2911)	0.09846424833902251
#   (0, 514)	0.21531096540841593
#   (0, 4437)	0.21913232243943245
#   (0, 9940)	0.1872637100467518
#   (0, 4384)	0.1283847088370484
#   (0, 1247)	0.11689495717979519
#   (0, 7281)	0.10596334477213287
#   (0, 8289)	0.08383925547827197
#   (0, 9844)	0.08388998340949928
#   (0, 8168)	0.11302390014352305
#   (0, 11378)	0.12608612524113474
#   (0, 4597)	0.06489312364298665
#   (0, 11650)	0.07513874997357489
#   (0, 6108)	0.05521543919905807
#   (0, 9581)	0.14922031081174122
#   (0, 745)	0.10719307590879197
#   (0, 8595)	0.15336062565051428
#   (0, 3689)	0.19617286746192367
#   (0, 4093)	0.18663642119797472
#   (0, 5182)	0.13604631855145147
#   (0, 6662)	0.08234564116248956
#   (0, 3154)	0.11243454823520445
#   (0, 4412)	0.30094042643962504

# %%
resume.shape
# Out:
# (2277, 3)

# %%
query = resume.iloc[[0]]

# %%
query
# Out:
#    id                                           all_text  \
# 0   0  Flutter Developer. We are looking for hire exp...
#
#                                           clean_text
# 0  flutter developer look hire experts flutter de...

# %%
# query = 'I am a flutter developer. I know python and I have wored with APIs and web development.'

# %%
from sklearn.metrics.pairwise import cosine_similarity

#convert query input to TF-IDF
user_tfidf = tfidf_vectorizer.transform(query['clean_text'])

#Calculate similarity score of query data with every record in the original data
cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf, x),tfidf_jobid)

# %%
output2 = list(cos_similarity_tfidf)

# %%
def get_recommendation(top, resume, scores):
  recommendation = pd.DataFrame(columns = ['id', 'clean_text', 'score'])
  count = 0
  for i in top:
      recommendation.at[count, 'id'] = resume['id'][i]
      recommendation.at[count, 'clean_text'] = resume['clean_text'][i]
      recommendation.at[count, 'score'] =  scores[count]
      count += 1
  return recommendation

# %%
top = sorted(range(len(output2)), key=lambda i: output2[i], reverse=True)[:10]
list_scores = [output2[i][0][0] for i in top]
results = get_recommendation(top,resume, list_scores)

# %%
results
# Out:
#      id                                         clean_text     score
# 0     0  flutter developer look hire experts flutter de...       1.0
# 1  1465  flutter developer look flutter developer train...  0.533002
# 2  1847  php developer good experience web development ...  0.501664
# 3  2133  flutter developer flutter developer create mul...  0.497085
# 4  2187  flutter developer look flutter developer profi...  0.454261
# 5  2059  php developer base company look wordpress php ...  0.424395
# 6   806  flutter developer minimum years hand flutter w...  0.424214
# 7   710  flutter developer years experience flutter app...  0.418807
# 8   375  flutter developer flutter developer mobile app...  0.411718
# 9  2093  ios developer hire iphone developer knowledge ...  0.411712

# %% [markdown]
# ### Using Word2Vec Deep Learning

# %%
# Importing necessary libraries here
import sys
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
from gensim.models import KeyedVectors
from gensim.models.word2vec import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

import warnings 
warnings.filterwarnings('ignore') # no warnings
# Out:
# C:\Users\zeeha\anaconda3\envs\python-r\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
#splitting the description into words
corpus = []
for words in resume['clean_text']:
    corpus.append(words.split())

# %%
#tag each document 
documents = [TaggedDocument(doc, [str(resume['id'][i])]) for i, doc in enumerate(corpus)]

# %%
max_epochs = 5
vec_size = 15
alpha = 0.025

dl_model = Doc2Vec(vector_size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1,
                epochs=max_epochs)
  
dl_model.build_vocab(documents)

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    dl_model.train(documents,
                total_examples=dl_model.corpus_count,
                epochs=dl_model.epochs)
    # decrease the learning rate
    dl_model.alpha -= 0.0002
    # fix the learning rate, no decay
    dl_model.min_alpha = dl_model.alpha
# Out:
# iteration 0
# iteration 1
# iteration 2
# iteration 3
# iteration 4

# %% [markdown]
# ### Tex Document/Record/Row representation in numerical feature

# %%
# row 1 in the data
resume['clean_text'][0]
# Out:
# 'flutter developer look hire experts flutter developer eligible post apply resume job type full time part time salary per month benefit flexible schedule food allowance schedule day shift supplemental pay join bonus overtime pay experience total work year prefer house rent subsidy yes industry software development work remotely temporarily due covid'

# %%
# row 1 in the data
dl_model[0]
# Out:
# array([-0.4282689 ,  1.1823119 , -0.0497436 , -0.35196477, -1.0450938 ,
#        -0.15550764,  1.2872359 ,  0.24296899, -1.8449079 ,  1.042119  ,
#        -0.05743349, -0.12619564, -0.37219805, -0.27012983,  0.03482505],
#       dtype=float32)

# %%
dl_model.wv.most_similar('python',topn=10)
# Out:
# [('scala', 0.9092966318130493),
#  ('perl', 0.8779366612434387),
#  ('ruby', 0.8612880706787109),
#  ('fore', 0.8072997331619263),
#  ('script', 0.8027686476707458),
#  ('nodejs', 0.7971122860908508),
#  ('rail', 0.7933678030967712),
#  ('comfortability', 0.7906734347343445),
#  ('java', 0.7844518423080444),
#  ('languages', 0.7808639407157898)]

# %%
dl_model.save("resume_doc2vec.model")

# %% [markdown]
# ### Testing Model

# %%
query = resume['clean_text'][0]
query
# Out:
# 'flutter developer look hire experts flutter developer eligible post apply resume job type full time part time salary per month benefit flexible schedule food allowance schedule day shift supplemental pay join bonus overtime pay experience total work year prefer house rent subsidy yes industry software development work remotely temporarily due covid'

# %%
query_data_tokenize = word_tokenize(query)
v1 = dl_model.infer_vector(query_data_tokenize)
similar_records=dl_model.dv.most_similar([v1])

# %%
similar_records
# Out:
# [('622', 0.9597906470298767),
#  ('2133', 0.951916515827179),
#  ('620', 0.9519001841545105),
#  ('806', 0.950456440448761),
#  ('1584', 0.9489269256591797),
#  ('2056', 0.9393699765205383),
#  ('2230', 0.937880277633667),
#  ('0', 0.9368845820426941),
#  ('2187', 0.9361637234687805),
#  ('2131', 0.9265946745872498)]

# %%
#Choose the index of the recommended data to see the quality/accuracy of recommendation
i = 0

# %%
idx = resume[resume['id']==int(similar_records[i][0])]
idx['score'] = similar_records[i][1]
idx
# Out:
#       id                                           all_text  \
# 604  622  Flutter Developer. We are Product based IT Com...
#
#                                             clean_text     score
# 604  flutter developer product base company look im...  0.959791

# %%
#Display full recommended data
resume['clean_text'][idx.index[0]]
# Out:
# 'flutter developer product base company look immediate joiners interest candidates please mention current ctc expect ctc join date job type full time walk salary per month schedule day shift experience software development year prefer work year prefer total work year prefer education bachelor prefer'
