# %%
import pandas as pd
import numpy as np
import scipy
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df = pd.read_csv('AutoMPG.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Unique value columns such as unique id, unique names should not be used in Machine Learning models

# %%
df = df.drop(['car name'],axis=1)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %% [markdown]
# ### Convention or Rule of Thumb is to call/denoted all the inputs as X and all the output/prediction/response as Y

# %%
X = df.drop(['mpg'],axis=1)
Y = df['mpg']

# %%
X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0         130    3504          12.0          70
# 1            8         350.0         165    3693          11.5          70
# 2            8         318.0         150    3436          11.0          70
# 3            8         304.0         150    3433          12.0          70
# 4            8         302.0         140    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0          86    2790          15.6          82
# 388          4          97.0          52    2130          24.6          82
# 389          4         135.0          84    2295          11.6          82
# 390          4         120.0          79    2625          18.6          82
# 391          4         119.0          82    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
Y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 387    27.0
# 388    44.0
# 389    32.0
# 390    28.0
# 391    31.0
# Name: mpg, Length: 392, dtype: float64

# %% [markdown]
# ### Simple Linear Regression between mpg and weight

# %% [markdown]
# Using just two variables. One input column and one output/prediction/response column. The reason behind using one input and one output is just to learn linear regression and see the model (straight line) on the 2-D plot

# %% [markdown]
# Coding Trick: Need to add constant everytime with your input. The reason for this is that it takes care of the bias (the intercept term b
#  is often called the bias parameter) in the data (a constant difference which is there for all observations).

# %%
X = sm.add_constant(X['weight'])

# %%
X
# Out:
#      const  weight
# 0      1.0    3504
# 1      1.0    3693
# 2      1.0    3436
# 3      1.0    3433
# 4      1.0    3449
# ..     ...     ...
# 387    1.0    2790
# 388    1.0    2130
# 389    1.0    2295
# 390    1.0    2625
# 391    1.0    2720
#
# [392 rows x 2 columns]

# %%
model = sm.OLS(Y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     789.4
# Date:                Thu, 10 Oct 2024   Prob (F-statistic):           9.49e-96
# Time:                        23:49:20   Log-Likelihood:                -1147.2
# No. Observations:                 392   AIC:                             2298.
# Df Residuals:                     390   BIC:                             2306.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         45.9223      0.835     55.020      0.000      44.281      47.563
# ...

# %%
model.pvalues
# Out:
# const     6.678078e-186
# weight     9.494425e-96
# dtype: float64

# %% [markdown]
# ### Interpretation of the above result

# %% [markdown]
# R-squared: 0.669 (any value above 0.3 usually shows good relationship between variables) <br>
# Y (prediction) = MPG <br> X (input) = weight <br> For each additional pound/kg of weight on the car (or for every unit increase in weight),
# the MPG decreases by 0.0076 miles

# %%
plt.plot(df['weight'].values, df['mpg'].values,'ro')
plt.plot(df['weight'].values ,model.fittedvalues.values,  'b')
plt.legend(['Data', 'Fitted model'])
plt.xlabel('weight')
plt.ylabel('mpg')
# Out:
# Text(0, 0.5, 'mpg')

# %% [markdown]
# ## Another Function for Linear Regression (Additional material)

# %%
model2 = ols("mpg ~ weight", data=df).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     789.4
# Date:                Thu, 10 Oct 2024   Prob (F-statistic):           9.49e-96
# Time:                        23:57:56   Log-Likelihood:                -1147.2
# No. Observations:                 392   AIC:                             2298.
# Df Residuals:                     390   BIC:                             2306.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     45.9223      0.835     55.020      0.000      44.281      47.563
# ...

# %%
model2.pvalues
# Out:
# Intercept    6.678078e-186
# weight        9.494425e-96
# dtype: float64

# %% [markdown]
# ### Interpretation of the above result

# %% [markdown]
# R-squared: 0.669 (any value above 0.3 usually shows good relationship between variables) <br>
# Y (prediction) = MPG <br> X (input) = weight <br> For each additional pound/kg of weight on the car (or for every unit increase in weight),
# the MPG decreases by -0.0076 miles

# %% [markdown]
# ## Seaborn to plot Regression Line (Additional Material)

# %%
#Seaborn
sns.lmplot(x='weight', y='mpg', data=df)

# %% [markdown]
# ## Multiple Linear Regression (all inputs)

# %%
# When you have more than one input

# %%
X = df.drop(['mpg'],axis=1)
Y = df['mpg']

# %%
X = sm.add_constant(X)

# %%
X
# Out:
#      const  cylinders  displacement  horsepower  weight  acceleration  \
# 0      1.0          8         307.0         130    3504          12.0
# 1      1.0          8         350.0         165    3693          11.5
# 2      1.0          8         318.0         150    3436          11.0
# 3      1.0          8         304.0         150    3433          12.0
# 4      1.0          8         302.0         140    3449          10.5
# ..     ...        ...           ...         ...     ...           ...
# 387    1.0          4         140.0          86    2790          15.6
# 388    1.0          4          97.0          52    2130          24.6
# 389    1.0          4         135.0          84    2295          11.6
# 390    1.0          4         120.0          79    2625          18.6
# 391    1.0          4         119.0          82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %%
modelall = sm.OLS(Y,X).fit()

# %%
modelall.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     202.6
# Date:                Fri, 11 Oct 2024   Prob (F-statistic):          1.02e-124
# Time:                        00:00:04   Log-Likelihood:                -1061.1
# No. Observations:                 392   AIC:                             2138.
# Df Residuals:                     384   BIC:                             2170.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
modelall.pvalues
# Out:
# const           2.445121e-03
# cylinders       2.219442e-01
# displacement    3.489171e-02
# horsepower      3.422865e-01
# weight          8.517298e-18
# acceleration    4.661220e-01
# model year      1.889664e-32
# origin          9.793188e-05
# dtype: float64

# %% [markdown]
# ### Interpretation of the above result

# %% [markdown]
# R-squared: 0.787 (any value above 0.3 usually shows good relationship between all input variables and output/response variable) <br><br>
# Y (prediction) = MPG <br> X (input) = weight <br> For each additional pound/kg of weight on the car (or for every unit increase in weight),
# the MPG decreases by 0.0065 miles <br><br>
# Y (prediction) = MPG <br> X (input) = model year <br> For each additional year (or for every unit increase in year),
# the MPG increases by 0.7319 miles <br>

# %% [markdown]
# ## Regression can't work with categorical inputs

# %% [markdown]
# ### One Hot Encoding - For converting categorical columns into numerical columns

# %%
df = pd.read_csv('AutoMPG.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Just creating a categorical column to show how one hot encoding works

# %%
df['Type'] = 'Old'

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name Type
# 0          70       1  chevrolet chevelle malibu  Old
# 1          70       1          buick skylark 320  Old
# 2          70       1         plymouth satellite  Old
# 3          70       1              amc rebel sst  Old
# 4          70       1                ford torino  Old

# %%
df.loc[df['model year'] > 70, 'Type'] = 'New'

# %%
df = df.drop('car name',axis=1)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin Type
# 0            70       1  Old
# 1            70       1  Old
# 2            70       1  Old
# ...

# %%
X = df.drop(['mpg'],axis=1)
Y = df['mpg']

# %%
X.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0          8         307.0         130    3504          12.0          70
# 1          8         350.0         165    3693          11.5          70
# 2          8         318.0         150    3436          11.0          70
# 3          8         304.0         150    3433          12.0          70
# 4          8         302.0         140    3449          10.5          70
#
#    origin Type
# 0       1  Old
# 1       1  Old
# 2       1  Old
# 3       1  Old
# 4       1  Old

# %%
Y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 387    27.0
# 388    44.0
# 389    32.0
# 390    28.0
# 391    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
X = sm.add_constant(X)

# %%
X.head()
# Out:
#    const  cylinders  displacement  horsepower  weight  acceleration  \
# 0    1.0          8         307.0         130    3504          12.0
# 1    1.0          8         350.0         165    3693          11.5
# 2    1.0          8         318.0         150    3436          11.0
# 3    1.0          8         304.0         150    3433          12.0
# 4    1.0          8         302.0         140    3449          10.5
#
#    model year  origin Type
# 0          70       1  Old
# 1          70       1  Old
# 2          70       1  Old
# 3          70       1  Old
# 4          70       1  Old

# %%
modelcat = sm.OLS(Y,X).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 modelcat = sm.OLS(Y,X).fit()
#
# File ~\anaconda3\envs\python-r\lib\site-packages\statsmodels\regression\linear_model.py:906, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     903     msg = ("Weights are not supported in OLS and will be ignored"
#     904            "An exception will be raised in the next version.")
#     905     warnings.warn(msg, ValueWarning)
# --> 906 super(OLS, self).__init__(endog, exog, missing=missing,
#     907                           hasconst=hasconst, **kwargs)
#     908 if "weights" in self._init_keys:
#     909     self._init_keys.remove("weights")
#
# File ~\anaconda3\envs\python-r\lib\site-packages\statsmodels\regression\linear_model.py:733, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     731 else:
# ...

# %% [markdown]
# ### We get the error above because Regression cannot process categorical columns
# ### Lets try one hot encoding

# %%
one_hot = pd.get_dummies(df, columns = ['Type'], dtype=int)

# %%
one_hot
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin  Type_New  Type_Old
# 0            70       1         0         1
# 1            70       1         0         1
# ...

# %%
X = one_hot.drop(['mpg'],axis=1)
Y = one_hot['mpg']

# %%
X = sm.add_constant(X)

# %%
X.head()
# Out:
#    const  cylinders  displacement  horsepower  weight  acceleration  \
# 0    1.0          8         307.0         130    3504          12.0
# 1    1.0          8         350.0         165    3693          11.5
# 2    1.0          8         318.0         150    3436          11.0
# 3    1.0          8         304.0         150    3433          12.0
# 4    1.0          8         302.0         140    3449          10.5
#
#    model year  origin  Type_New  Type_Old
# 0          70       1         0         1
# 1          70       1         0         1
# 2          70       1         0         1
# 3          70       1         0         1
# 4          70       1         0         1

# %%
modelcat = sm.OLS(Y,X).fit()

# %%
modelcat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.787
# Method:                 Least Squares   F-statistic:                     181.1
# Date:                Fri, 11 Oct 2024   Prob (F-statistic):          4.34e-125
# Time:                        00:14:53   Log-Likelihood:                -1057.4
# No. Observations:                 392   AIC:                             2133.
# Df Residuals:                     383   BIC:                             2169.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Why we fit models?
# ### Because we want to predict values (output) for new/unknown things (inputs)

# %% [markdown]
# ### Lets save the model first in a file

# %%
# Save the model to disk
filename = 'regmodelcat.pkl'
pickle.dump(modelcat, open(filename, 'wb'))

# %% [markdown]
# ### Lets load the model first in a file

# %%
# Load the model from disk
loaded_model = pickle.load(open('regmodelcat.pkl', 'rb'))

# %% [markdown]
# As of now, you can use either model_cat or loaded_model since they both are present in this notebook. For prediction on other notebooks, you can skip the fit() process and just load the saved model to do predictions. You dont even have to read the csv data file.

# %% [markdown]
# ### Lets create one new input (car) and predict its output (mpg)

# %%
df_new = pd.DataFrame({'const': [1.0],
                       'cylinders':[8],
                       'displacement':[307],
                       'horsepower': [130],
                       'weight': [3504],
                       'acceleration': [12],
                       'model year':[70],
                       'origin': [1],
                       'Type_New': [0],
                       'Type_Old':[1]})

# %%
df_new
# Out:
#    const  cylinders  displacement  horsepower  weight  acceleration  \
# 0    1.0          8           307         130    3504            12
#
#    model year  origin  Type_New  Type_Old
# 0          70       1         0         1

# %% [markdown]
# ### We have already trained a model above. No need to train again. Just predict

# %%
#predicting mpg for new data using modelcat
modelcat.predict(df_new)
# Out:
# 0    16.777048
# dtype: float64

# %%
#predicting mpg for new data using loaded_model
loaded_model.predict(df_new)
# Out:
# 0    16.777048
# dtype: float64

# %% [markdown]
# ### Interpretation

# %% [markdown]
# #### For the new car, the predicted MPG is 16.77 using our regression model

# %% [markdown]
# ### Lets create multiple new inputs (cars) and predict their outputs (mpg). Here we have 3 new car inputs

# %%
df_new = pd.DataFrame({'const': [1.0,1.0,1.0],
                       'cylinders':[8,7,6],
                       'displacement':[307,308,666],
                       'horsepower': [130,150,100],
                       'weight': [3504,1000,2000],
                       'acceleration': [12,10,15],
                       'model year':[70,80,90],
                       'origin': [1,1,0],
                       'Type_New': [0,1,1],
                       'Type_Old':[1,0,0]})

# %%
df_new
# Out:
#    const  cylinders  displacement  horsepower  weight  acceleration  \
# 0    1.0          8           307         130    3504            12
# 1    1.0          7           308         150    1000            10
# 2    1.0          6           666         100    2000            15
#
#    model year  origin  Type_New  Type_Old
# 0          70       1         0         1
# 1          80       1         1         0
# 2          90       0         1         0

# %%
modelcat.predict(df_new)
# Out:
# 0    16.777048
# 1    37.022174
# 2    45.468016
# dtype: float64

# %% [markdown]
# ## Extra Library for Regression (no good summary)

# %% [markdown]
# #### Using Scikit-Learn Library

# %%
from sklearn.linear_model import LinearRegression

# %%
reg_alg = LinearRegression()

# %%
regmodel = reg_alg.fit(X, Y)

# %%
print(regmodel.intercept_, regmodel.coef_, regmodel.score(X, Y))
# Out:
# -18.634581044726787 [ 0.         -0.45863155  0.01604073 -0.02513288 -0.00589307  0.0479099
#   0.78759655  1.23445713 -1.13164493  1.13164493] 0.7908707801224332
